# %% [markdown]
# # Loading the data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=Warning)

# %%
pd.set_option("display.max_rows", 100)

# %%
df = pd.read_excel("results/bank_data_clean.xlsx")

# %%
# group by month and sum the quantities
df.groupby(by="month")["quantity"].sum()
expenses=df[df["quantity"]<0]
expenses["quantity"] = expenses["quantity"] * -1 #change of sign
expenses["day"] = expenses["date"].map(lambda x: x.day) #new column day
exp_by_month = expenses.groupby(by="month")["quantity"].sum().reset_index()
expenses_by_day = expenses.groupby(by=["month", "day"])["quantity"].sum().reset_index() #group by day

# %% [markdown]
# # Overall month comparison:

# %%
exp_by_month.plot(x="month", y="quantity", kind="bar", title="expenses by month")
plt.show()

# %%
months = exp_by_month["month"].unique().tolist()
for month in months: 
    # 1. filter data by month
    filtered_month = exp_by_month[exp_by_month["month"]==month]
    # 2. calculate total expenses
    monthly_exp  = filtered_month["quantity"].sum()
    # 3. Print result
    print(f"total expenses for month {month}: {monthly_exp} €")
# Out:
# total expenses for month 1: 228.89 €
# total expenses for month 2: 562.74 €
# total expenses for month 3: 323.6 €
# total expenses for month 4: 530.9 €
# total expenses for month 5: 651.37 €
# total expenses for month 6: 602.0 €
# total expenses for month 7: 678.62 €
# total expenses for month 8: 574.89 €
# total expenses for month 9: 716.03 €

# %%
def monthly_table(month_number: int, data: pd.DataFrame = expenses) -> pd.DataFrame:
    month_filter = data["month"] == month_number
    month_data = data[month_filter]
    return month_data

# %%
def monthly_graph(month_number: int):
    filter3 = expenses_by_day["month"] == month_number
    data = expenses_by_day[filter3]
    data.plot(x="day", y="quantity", kind = "bar", title="monthly expenses")
    plt.show()

# %% [markdown]
# # January

# %%
monthly_table(1)
# Out:
#          date                                            concept  quantity  \
# 72 2022-01-27     Compra Rewe Reutlingen/ri, Reutlingen, Tarjeta     62.16
# 73 2022-01-21       Compra Penny Ringelbach, Reutlingen, Tarjeta     22.75
# 74 2022-01-19  Bizum A Favor De Elisa Aghina Garcia Concepto:...     19.00
# 75 2022-01-03       Compra Hellofresh*259452737, Berlin, Tarjeta     40.25
# 76 2022-01-03  Compra Www.aireu0not-availabl, Llucmajor, Tarjeta     74.73
# 77 2022-01-03  Compra Www.aireu0not-availabl, Llucmajor, Tarjeta     10.00
#
#      saldo  month  day
# 72  282.12      1   27
# 73  344.28      1   21
# 74  367.03      1   19
# 75  386.03      1    3
# 76  426.28      1    3
# 77  501.01      1    3

# %%
monthly_graph(1)

# %% [markdown]
# # February

# %%
monthly_table(2)
# Out:
#           date                                            concept  quantity  \
# 78  2022-02-28   Compra Wiener Feinbäcker 5543, Eschborn, Tarjeta      3.80
# 79  2022-02-28  Compra Baeckerei Schaan Fil., Frankfurt Am, Ta...      8.45
# 80  2022-02-28  Compra Parkhaus Betriebs-gmbh, Frankfurt Am, T...      4.00
# 81  2022-02-28      Compra Tegut Filiale 2348, Frankfurt, Tarjeta     13.40
# 82  2022-02-28  Compra Aldi Sued, Frankfurt, Tarjeta 516383010...     56.75
# 83  2022-02-25    Compra Doori Kaiserstrasse, Langenfeld, Tarjeta     16.60
# 84  2022-02-24              Compra Ryanair G3s0, K67ny94, Tarjeta     78.83
# 85  2022-02-24    Compra Lappkaﬀenberger Eschb, Eschborn, Tarjeta     13.95
# 86  2022-02-23  Compra Galeria Restaurant Gmb, Frankfurt, Tarjeta      7.90
# 87  2022-02-23          Compra Toprak Gmbh, Frankfurt Am, Tarjeta     20.00
# 88  2022-02-23         Compra Paulaner Am Dom, Frankfurt, Tarjeta     34.00
# 89  2022-02-23  Reintegro En Santander Bank Atm, Frankfurt, Ta...     80.00
# 90  2022-02-23  Compra H&m Frankfurt 1de0667, Frankfurt Am, Ta...     25.14
# 91  2022-02-16  Compra Www.aireu0not-availabl, Llucmajor, Tarjeta     20.23
# 92  2022-02-15  Compra Parkhaus Betriebs-gmbh, Frankfurt Am, T...      3.00
# 94  2022-02-07  Compra Studioline Frankfurtgm, Frankfurt, Tarjeta     49.99
# 95  2022-02-07  Compra Five Guys Germany Gmbh, Frankfurt, Tarjeta     11.10
# 98  2022-02-03      Compra Tegut Filiale 2348, Frankfurt, Tarjeta     77.42
# 99  2022-02-02   Compra Wiener Feinbäcker 5543, Eschborn, Tarjeta      5.55
# 100 2022-02-01               Compra Omv 7668, Reutlingen, Tarjeta     32.63
#
#       saldo  month  day
# 78   176.38      2   28
# 79   180.18      2   28
# 80   188.63      2   28
# 81   192.63      2   28
# 82   206.03      2   28
# 83   262.78      2   25
# 84   279.38      2   24
# 85   358.21      2   24
# 86   372.16      2   23
# 87   380.06      2   23
# 88   400.06      2   23
# 89   434.06      2   23
# 90   514.06      2   23
# 91   539.20      2   16
# 92   559.43      2   15
# 94   162.43      2    7
# 95   212.42      2    7
# 98   166.52      2    3
# 99   243.94      2    2
# 100  249.49      2    1

# %%
monthly_graph(2)

# %% [markdown]
# # March

# %%
monthly_table(3)
# Out:
#           date                                            concept  quantity  \
# 166 2022-03-29  Bizum A Favor De Gabriel Blanco Garcia Concept...      1.20
# 167 2022-03-22  Compra Kokono Wuerzburg Resta, Wuerzburg, Tarjeta     31.00
# 168 2022-03-16     Compra Bologna Centrale Self, Bologna, Tarjeta      7.70
# 169 2022-03-15           Compra Db Vertrieb Gmbh, G2qbm1, Tarjeta     12.09
# 170 2022-03-15  Compra Bounty, Bologna, Tarjeta 51638301070289...     23.50
# 171 2022-03-15  Compra Sanifair Nuernberg Hbf, Nuernberg, Tarjeta      1.00
# 172 2022-03-15            Compra Autogrill 7315, Bologna, Tarjeta      2.50
# 173 2022-03-15         Compra Blq Schengen Shop, Bologna, Tarjeta      3.00
# 174 2022-03-15           Compra Db Vertrieb Gmbh, U3q7yx, Tarjeta     12.09
# 175 2022-03-15    Compra Marconi Express Pay&go, Bologna, Tarjeta      9.20
# 176 2022-03-14           Compra Db Vertrieb Gmbh, D89p16, Tarjeta     12.09
# 177 2022-03-14  Compra Sal Srl, Modena, Tarjeta 51638301070289...      6.00
# 178 2022-03-11  Compra Trainline Sas, Paris, Tarjeta 516383010...     18.90
# 179 2022-03-11  Compra Trainline.sas, Paris, Tarjeta 516383010...     36.20
# 180 2022-03-10  Compra Vg Schillingsfürst, Schillingsfür, Tarjeta     13.00
# 181 2022-03-10       Compra Brothaus Gmbh, Rothenburg Ob, Tarjeta     13.20
# 182 2022-03-08      Compra De01401 - Skyli, Frankfurt Am, Tarjeta     10.00
# 183 2022-03-08      Compra Osiander Frankfurt, Frankfurt, Tarjeta     26.50
# 184 2022-03-08  Compra Baeckerei Schaan Fil., Frankfurt Am, Ta...      9.00
# 185 2022-03-08        Compra Zoo Frankfurt, Frankfurt Am, Tarjeta     25.00
# 187 2022-03-07      Compra Rewe Frankfurt/mai, Frankfurt, Tarjeta      3.53
# 188 2022-03-04        Transferencia A Favor De Cruz Roja Española     20.00
# 189 2022-03-03  Compra Rmv App / Rmv Smart Ap, Frankfurt Am, T...     26.90
#
#       saldo  month  day
# 166   52.78      3   29
# 167   53.98      3   22
# 168   84.98      3   16
# 169   92.68      3   15
# 170  104.77      3   15
# 171  128.27      3   15
# 172  129.27      3   15
# 173  131.77      3   15
# 174  134.77      3   15
# 175  146.86      3   15
# 176  156.06      3   14
# 177  168.15      3   14
# 178  174.15      3   11
# 179  193.05      3   11
# 180  229.25      3   10
# 181  242.25      3   10
# 182  255.45      3    8
# 183  265.45      3    8
# 184  291.95      3    8
# 185  300.95      3    8
# 187  125.95      3    7
# 188  129.48      3    4
# 189  149.48      3    3

# %%
monthly_graph(3)

# %% [markdown]
# # April

# %%
monthly_table(4)
# Out:
#          date                                            concept  quantity  \
# 48 2022-04-28  Compra Amzndigital*2p1p08544, Luxembourg, Tarjeta      5.12
# 50 2022-04-25   Compra Rewe Frankfurt/nor, Frankfurt Am, Tarjeta      4.13
# 51 2022-04-25           Compra Db Vertrieb Gmbh, Kblqpv, Tarjeta     21.50
# 53 2022-04-20  Compra Internet En Renfe Virtual I, Madrid, Ta...     72.45
# 54 2022-04-20  Compra Internet En Renfe Virtual I, Madrid, Ta...     80.50
# 55 2022-04-18  Compra Parkhaus Hauptwache, Frankfurt Am, Tarjeta      4.00
# 56 2022-04-18     Compra Sumup *yomaro Heinze, Wurzburg, Tarjeta      4.70
# 57 2022-04-18               Compra Dean&david, Würzburg, Tarjeta     13.65
# 58 2022-04-18    Compra Hotel Roter Hahn, Rothenburg Ob, Tarjeta     19.00
# 59 2022-04-14               Compra Flightgib, Amsterdam, Tarjeta     75.00
# 60 2022-04-12  Compra Gibson Gmbh & Co. Kg, Frankfurt Am, Tar...     11.50
# 61 2022-04-12       Compra Amzn Mktp De*2e7u85t64, 800-279-6620,     18.38
# 62 2022-04-12          Compra Toprak Gmbh, Frankfurt Am, Tarjeta     20.00
# 63 2022-04-12               Compra Shein.com, Shein.com, Tarjeta     51.97
# 64 2022-04-11  Compra Aldi Sued, Frankfurt, Tarjeta 516383010...      4.29
# 65 2022-04-11           Compra Tier De 4-563600, Berlin, Tarjeta      2.90
# 66 2022-04-06  Compra Alex Skyline Plaza Fra, Frankfurt, Tarjeta     19.00
# 67 2022-04-04     Compra Rewe Linda Menig Ohg, Woernitz, Tarjeta      5.53
# 68 2022-04-04        Compra Gce Service Gmbh, Frankfurt, Tarjeta     26.00
# 69 2022-04-04  Compra Rmv App / Rmv Smart Ap, Frankfurt Am, T...     16.20
# 70 2022-04-04   Bizum A Favor De Gabriel Blanco Garcia Concepto:     25.00
# 71 2022-04-01       Compra Rewe Frankfurt, Frankfurt Am, Tarjeta     30.08
#
#      saldo  month  day
# 48  621.88      4   28
# 50  227.00      4   25
# 51  231.13      4   25
# 53   52.63      4   20
# 54  125.08      4   20
# 55  205.58      4   18
# 56  209.58      4   18
# 57  214.28      4   18
# 58  227.93      4   18
# 59  246.93      4   14
# 60  321.93      4   12
# 61  333.43      4   12
# 62  351.81      4   12
# 63  371.81      4   12
# 64  423.78      4   11
# 65  428.07      4   11
# 66  430.97      4    6
# 67  449.97      4    4
# 68  455.50      4    4
# 69  481.50      4    4
# 70  497.70      4    4
# 71  522.70      4    1

# %%
monthly_graph(4)

# %% [markdown]
# # May

# %%
filt5 = expenses["month"]==5
may = expenses[filt5]
may
# Out:
#           date                                            concept  quantity  \
# 190 2022-05-31          Compra Lu5han2202476940248, Koln, Tarjeta    100.69
# 191 2022-05-31  Compra Ticket.io, Koln, Tarjeta 51638301070289...     51.19
# 192 2022-05-30  Compra Selecta Deutschland Gm, Kelsterbach, Ta...      3.30
# 193 2022-05-30         Compra Main Terasse, Frankfurt Am, Tarjeta     23.00
# 194 2022-05-30  Transaccion Contactless En Grupo Sup Ahorr, Ma...     13.90
# 195 2022-05-30  Transaccion Contactless En Herjomar, Madrid, T...     14.25
# 196 2022-05-27  Compra Aral StaTon 120933007, Frankfurt Am, Ta...     19.98
# 197 2022-05-27       Compra Rewe Frankfurt, Frankfurt Am, Tarjeta     12.44
# 198 2022-05-26      Compra Tegut Filiale 2348, Frankfurt, Tarjeta     11.87
# 199 2022-05-25  Compra Alex Skyline Plaza Fra, Frankfurt, Tarjeta     20.00
# 200 2022-05-24  Compra Städelsches KunsTnsT, Frankfurt Am, Tar...     16.00
# 201 2022-05-24  Compra Baeckerei Schaan Fil., Frankfurt Am, Ta...      9.30
# 202 2022-05-23       Compra Amzn Mktp De*257ys1xl4, 800-279-6620,     22.84
# 203 2022-05-23           Compra Main Tower, Frankfurt Am, Tarjeta      6.00
# 204 2022-05-23    Compra Klosterhof Frankfurt, Frankfurt, Tarjeta     20.70
# 205 2022-05-23   Compra Hilton Fra Airport, Frankfurt Am, Tarjeta      5.00
# 206 2022-05-20            Compra Aldi Sued, Frankfurt Am, Tarjeta      1.94
# 207 2022-05-19       Compra Rewe Frankfurt, Frankfurt Am, Tarjeta     16.98
# 208 2022-05-16  Compra Commerzbank Kasino Ffm, Frankfurt Am, T...      2.60
# 209 2022-05-16       Compra Rewe Frankfurt, Frankfurt Am, Tarjeta     27.57
# 210 2022-05-16          Compra Tier De 5-1326265, Berlin, Tarjeta      3.09
# 212 2022-05-13   Transferencia A Favor De Max Horstmann Concepto:     11.00
# 213 2022-05-13  Compra Commerzbank Kasino Ffm, Frankfurt Am, T...      2.25
# 214 2022-05-12  Compra Aldi Sued, Frankfurt, Tarjeta 516383010...     13.67
# 215 2022-05-09   Compra En Transys Madrid, Madrid, Tarj. :*028955      1.70
# 216 2022-05-09  Transaccion Contactless En Burger King San, Ma...      8.45
# 217 2022-05-06  Compra Vodafone Gmbh Callya, Duesseldorf, Tarjeta     15.00
# 218 2022-05-06  Transaccion Contactless En Leinermut, Madrid, ...     28.00
# 219 2022-05-06  Compra Internet En ViveTx, Madrid, Tarj. :*028955     22.00
# 220 2022-05-06   Compra En Transys Madrid, Madrid, Tarj. :*028955      1.70
# 221 2022-05-06   Compra En Transys Madrid, Madrid, Tarj. :*028955      1.70
# 222 2022-05-05    Transaccion Contactless En Zara Madrid Pla, San     60.00
# 223 2022-05-03   Bizum A Favor De Miriam Torres Marquez Concepto:     12.00
# 224 2022-05-03  Compra Rmv App / Rmv Smart Ap, Frankfurt Am, T...     25.95
# 225 2022-05-03  Transaccion Contactless En Supermercados M, Pa...      7.79
# 226 2022-05-03  Transaccion Contactless En Dia S.a. Dos He, Pa...      3.77
# 227 2022-05-02  Compra Selecta Deutschland Gm, Kelsterbach, Ta...      3.30
# 228 2022-05-02  Bizum A Favor De Laura Bellido Seda Concepto: ...      6.50
# 229 2022-05-02  Transaccion Contactless En Metro De Sevill, Se...     10.00
# 230 2022-05-02  Transaccion Contactless En Farmacia Jose S, Ma...     13.95
#
#       saldo  month  day
# 190  370.51      5   31
# 191  471.20      5   31
# 192  522.39      5   30
# 193  525.69      5   30
# 194  548.69      5   30
# 195  562.59      5   30
# 196  576.84      5   27
# 197  596.82      5   27
# 198  609.26      5   26
# 199  621.13      5   25
# 200  641.13      5   24
# 201  657.13      5   24
# 202  666.43      5   23
# 203  689.27      5   23
# 204  695.27      5   23
# 205  715.97      5   23
# 206  720.97      5   20
# 207  722.91      5   19
# 208  739.89      5   16
# 209  742.49      5   16
# 210  770.06      5   16
# 212  373.15      5   13
# 213  384.15      5   13
# 214  386.40      5   12
# 215  400.07      5    9
# 216  401.77      5    9
# 217  410.22      5    6
# 218  425.22      5    6
# 219  453.22      5    6
# 220  475.22      5    6
# 221  476.92      5    6
# 222  478.62      5    5
# 223  538.62      5    3
# 224  550.62      5    3
# 225  576.57      5    3
# 226  584.36      5    3
# 227  588.13      5    2
# 228  591.43      5    2
# 229  597.93      5    2
# 230  607.93      5    2

# %%
monthly_graph(5)

# %% [markdown]
# # June

# %%
monthly_table(6)
# Out:
#           date                                            concept  quantity  \
# 135 2022-06-30           Compra Db Vertrieb Gmbh, Hkowow, Tarjeta     22.55
# 137 2022-06-28  Compra Internet En Renfe Virtual I, Madrid, Ta...     80.50
# 139 2022-06-27               Compra Shell 1936, Woernitz, Tarjeta     45.30
# 140 2022-06-27  Compra Toogoodtog 36jz56oail5, Toogoodtogo.d, ...      3.90
# 141 2022-06-27      Compra Smart Tickets.de Gmbh, Berlin, Tarjeta     44.00
# 142 2022-06-27  Bizum A Favor De Gabriel Blanco Garcia Concept...     36.50
# 143 2022-06-27  Bizum A Favor De Gabriel Blanco Garcia Concept...     44.34
# 144 2022-06-21            Compra Edeka Ebner, Oberstdorf, Tarjeta     17.23
# 145 2022-06-20          Compra Nebelhornbahn, Oberstdorf, Tarjeta      3.40
# 146 2022-06-20          Compra Nebelhornbahn, Oberstdorf, Tarjeta     30.60
# 147 2022-06-20  Bizum A Favor De Gabriel Blanco Garcia Concept...     37.25
# 149 2022-06-15   Bizum A Favor De Gabriel Blanco Garcia Concepto:     16.00
# 150 2022-06-14  Compra Portopino Cafe Gelater, Tuebingen, Tarjeta      4.00
# 151 2022-06-14      Compra Edeka A-m. Schoeck, Riederich, Tarjeta     13.12
# 152 2022-06-14   Compra Zampano Pizza & Pa, Frankfurt Am, Tarjeta     30.00
# 153 2022-06-13  Compra Vodafone Gmbh Callya, Duesseldorf, Tarjeta     15.00
# 154 2022-06-13               Compra Aldi Sued, Metzingen, Tarjeta     30.78
# 155 2022-06-13   Bizum A Favor De Gabriel Blanco Garcia Concepto:     21.00
# 156 2022-06-13  Bizum A Favor De Gabriel Blanco Garcia Concept...     12.00
# 157 2022-06-07   Bizum A Favor De Gabriel Blanco Garcia Concepto:     23.00
# 158 2022-06-06  Compra Rmv App / Rmv Smart Ap, Frankfurt Am, T...     26.75
# 159 2022-06-06   Compra Sumup *freigut Bootsh, Frankfurt, Tarjeta      7.00
# 160 2022-06-06      Compra Rewe Tuebingen/inn, Tuebingen, Tarjeta      4.78
# 162 2022-06-06   Bizum A Favor De Gabriel Blanco Garcia Concepto:     21.00
# 163 2022-06-03  Compra Toogoodtog Qpy7biovtro, Toogoodtogo.d, ...      3.00
# 164 2022-06-03           Compra Db Vertrieb Gmbh, Dcc9ao, Tarjeta      9.00
#
#       saldo  month  day
# 135  261.51      6   30
# 137  231.06      6   28
# 139  296.56      6   27
# 140  341.86      6   27
# 141  345.76      6   27
# 142  389.76      6   27
# 143  426.26      6   27
# 144  470.60      6   21
# 145  487.83      6   20
# 146  491.23      6   20
# 147  521.83      6   20
# 149  159.08      6   15
# 150  175.08      6   14
# 151  179.08      6   14
# 152  192.20      6   14
# 153  222.20      6   13
# 154  237.20      6   13
# 155  267.98      6   13
# 156  288.98      6   13
# 157  300.98      6    7
# 158  323.98      6    6
# 159  350.73      6    6
# 160  357.73      6    6
# 162  337.51      6    6
# 163  358.51      6    3
# 164  361.51      6    3

# %%
monthly_graph(6)

# %% [markdown]
# # July

# %%
monthly_table(7)
# Out:
#           date                                            concept  quantity  \
# 101 2022-07-26   Bizum A Favor De Gabriel Blanco Garcia Concepto:     47.00
# 102 2022-07-25           Compra Lecker Ole, Frankfurt Am, Tarjeta      7.21
# 103 2022-07-25  Bizum A Favor De Gabriel Blanco Garcia Concept...     27.00
# 104 2022-07-22   Bizum A Favor De Gabriel Blanco Garcia Concepto:     30.00
# 106 2022-07-20  Bizum A Favor De Alba Cruz Borrero Concepto: H...    189.00
# 107 2022-07-19  Compra Aral StaWon 220062186, Rothenburg Ob, T...      1.74
# 108 2022-07-19  Compra Shell 5606, Rodgau, Tarjeta 51638301070...     24.80
# 109 2022-07-18     Compra Fra Airport Parking, Frankfurt, Tarjeta      5.00
# 110 2022-07-18     Compra Fra Airport Parking, Frankfurt, Tarjeta      1.00
# 111 2022-07-18      Compra Rewe Frankfurt/mai, Frankfurt, Tarjeta      1.83
# 112 2022-07-18     Compra Fra Airport Parking, Frankfurt, Tarjeta      1.00
# 113 2022-07-18     Compra Fra Airport Parking, Frankfurt, Tarjeta      1.00
# 114 2022-07-18  Compra Wiener Feinbackerei 1, Muhlheim Am M, T...      6.20
# 115 2022-07-18  Compra Subway 56823 Rothenbur, Rothenburg, Tar...     13.38
# 116 2022-07-18  Bizum A Favor De Gabriel Blanco Garcia Concept...     11.50
# 117 2022-07-14           Compra Lecker Ole, Frankfurt Am, Tarjeta     11.20
# 119 2022-07-11        Compra Celona Frankfurt, Frankfurt, Tarjeta     15.00
# 120 2022-07-11   Compra Long Island Summer L., Frankfurt, Tarjeta      5.00
# 121 2022-07-11   Compra Long Island Summer L., Frankfurt, Tarjeta     11.50
# 122 2022-07-11       Compra Eschenheimer Turm, Frankfurt, Tarjeta      8.00
# 123 2022-07-08  Compra Internet En Renfe Virtual I, Madrid, Ta...     20.15
# 124 2022-07-07       Compra Rewe Frankfurt, Frankfurt Am, Tarjeta      3.57
# 125 2022-07-06      Compra Tegut Filiale 2348, Frankfurt, Tarjeta      2.24
# 126 2022-07-05  Compra Vodafone Gmbh Callya, Duesseldorf, Tarjeta     15.00
# 127 2022-07-05  Bizum A Favor De Gabriel Blanco Garcia Concept...     38.88
# 128 2022-07-05  Bizum A Favor De Andrea De La Mora Miranda Con...     22.00
# 129 2022-07-04  Compra Calzedonia Germany Gmb, Frankfurt Am, T...     30.00
# 130 2022-07-04     Compra Lidl Dienstleistung, Wuerzburg, Tarjeta     11.19
# 132 2022-07-04  Compra Internet En Air Europa, Llucmajor, Tarj...     81.38
# 133 2022-07-04  Bizum A Favor De Gabriel Blanco Garcia Concept...     27.21
# 134 2022-07-01      Compra Tegut Filiale 2348, Frankfurt, Tarjeta      8.64
#
#       saldo  month  day
# 101  321.89      7   26
# 102  368.89      7   25
# 103  376.10      7   25
# 104  403.10      7   22
# 106  244.10      7   20
# 107  433.10      7   19
# 108  434.84      7   19
# 109  459.64      7   18
# 110  464.64      7   18
# 111  465.64      7   18
# 112  467.47      7   18
# 113  468.47      7   18
# 114  469.47      7   18
# 115  475.67      7   18
# 116  489.05      7   18
# 117  500.55      7   14
# 119  111.75      7   11
# 120  126.75      7   11
# 121  131.75      7   11
# 122  143.25      7   11
# 123  151.25      7    8
# 124  171.40      7    7
# 125  174.97      7    6
# 126  177.21      7    5
# 127  192.21      7    5
# 128  231.09      7    5
# 129  253.09      7    4
# 130  283.09      7    4
# 132  144.28      7    4
# 133  225.66      7    4
# 134  252.87      7    1

# %%
monthly_graph(7)

# %% [markdown]
# # August

# %%
monthly_table(8)
# Out:
#          date                                            concept  quantity  \
# 0  2022-08-29  Compra Heberer Acm Frankfurt, Frankfurt Am, Ta...      8.80
# 1  2022-08-26             Compra Portugal Tolls, Almada, Tarjeta      6.62
# 2  2022-08-26  Compra Internet En Air Europa, Llucmajor, Tarj...      5.00
# 3  2022-08-22  Transaccion Contactless En Madrid Fuencarr, Ma...     19.99
# 4  2022-08-22  Transaccion Contactless En Montaditos Prin, Ma...      3.50
# 5  2022-08-22  Transaccion Contactless En Montaditos Prin, Ma...      3.00
# 6  2022-08-22  Transaccion Contactless En Calzedonia, Madrid,...     15.15
# 7  2022-08-22  Transaccion Contactless En Perfumeria Prim, Ma...      5.58
# 8  2022-08-19             Compra Portugal Tolls, Almada, Tarjeta      7.36
# 9  2022-08-19           Compra Sevilla - Lagoh, Sevilla, Tarjeta     32.00
# 11 2022-08-17  Compra Pingo Doce, Lagos, Tarjeta 516383010702...      2.78
# 12 2022-08-17  Compra Pingo Doce, Lagos, Tarjeta 516383010702...      3.00
# 13 2022-08-17          Compra Arm-soc Algarvia De, Faro, Tarjeta     30.00
# 14 2022-08-17  Compra Bon Vivant, Faro, Tarjeta 5163830107028...     20.00
# 15 2022-08-17  Bizum A Favor De Inmaculada Fernandez Cien Con...     12.80
# 16 2022-08-17  Transaccion Contactless En Pull And Bear, Sevi...     30.09
# 17 2022-08-17  Transaccion Contactless En MulXopXcas La, Sevi...     39.00
# 18 2022-08-17  Transaccion Contactless En Dia S.a. Dos He, Pa...      7.12
# 19 2022-08-17  Bizum A Favor De Inmaculada Fernandez Cien Con...     14.00
# 20 2022-08-16   Compra Ale-hop, Faro, Tarjeta 5163830107028955 ,     10.20
# 21 2022-08-16          Compra Restaurante Veneza, Lagos, Tarjeta     38.80
# 22 2022-08-16  Compra Spar Lagos, Lagos, Tarjeta 516383010702...     13.67
# 23 2022-08-16  Compra Muchacha, Lagos, Tarjeta 51638301070289...      3.00
# 24 2022-08-16  Compra Muchacha, Lagos, Tarjeta 51638301070289...      3.00
# 25 2022-08-16  Compra Muchacha, Lagos, Tarjeta 51638301070289...      4.50
# 26 2022-08-16  Transaccion Contactless En Bar Aljibe, Sevilla...      2.20
# 27 2022-08-16  Transaccion Contactless En Bar Aljibe, Sevilla...      2.20
# 28 2022-08-16  Transaccion Contactless En Bar Aljibe, Sevilla...      2.20
# 29 2022-08-16  Transaccion Contactless En Bar Aljibe, Sevilla...      6.00
# 30 2022-08-12  Compra Kauﬂand Rothenburg Ob, Rothenburg Ob, T...     29.84
# 31 2022-08-12    Compra Flgh .muenchen Mydutyf, München, Tarjeta      7.90
# 32 2022-08-11  Compra Vodafone Gmbh Callya, Duesseldorf, Tarjeta     15.00
# 33 2022-08-11          Compra Brothaus Gmbh, Rothenburg, Tarjeta      3.29
# 34 2022-08-11     Compra Kathe Wohlfahrt, Rothenburg O., Tarjeta     15.90
# 35 2022-08-11  Bizum A Favor De Alba Cruz Borrero Concepto: G...     30.00
# 36 2022-08-11  Transaccion Contactless En Taberna Alquita, Ma...     12.40
# 37 2022-08-08  Compra Huebn, Nuernberg, Tarjeta 5163830107028...     38.00
# 38 2022-08-08    Compra Penny Wuerzburg City, Wuerzburg, Tarjeta      1.54
# 39 2022-08-08     Compra Rewe Linda Menig Ohg, Woernitz, Tarjeta      1.88
# 40 2022-08-08     Compra Sumup *yomaro Heinze, Wurzburg, Tarjeta      6.80
# 41 2022-08-08             Compra Alter Kranen, Würzburg, Tarjeta      9.20
# 43 2022-08-05      Compra E Center Baechner, Rothenburg, Tarjeta     11.25
# 44 2022-08-04     Compra Rewe Linda Menig Ohg, Woernitz, Tarjeta     10.92
# 45 2022-08-03  Compra Rmv App / Rmv Smart Ap, Frankfurt Am, T...      9.00
# 46 2022-08-02           Compra Db Vertrieb Gmbh, 87atxz, Tarjeta      9.00
# 47 2022-08-01      Compra Tegut Filiale 2348, Frankfurt, Tarjeta     11.41
#
#      saldo  month  day
# 0   247.00      8   29
# 1   255.80      8   26
# 2   262.42      8   26
# 3   267.42      8   22
# 4   287.41      8   22
# 5   290.91      8   22
# 6   293.91      8   22
# 7   309.06      8   22
# 8   314.64      8   19
# 9   322.00      8   19
# 11  154.00      8   17
# 12  156.78      8   17
# 13  159.78      8   17
# 14  189.78      8   17
# 15  209.78      8   17
# 16  222.58      8   17
# 17  252.67      8   17
# 18  291.67      8   17
# 19  298.79      8   17
# 20  312.79      8   16
# 21  322.99      8   16
# 22  361.79      8   16
# 23  375.46      8   16
# 24  378.46      8   16
# 25  381.46      8   16
# 26  385.96      8   16
# 27  388.16      8   16
# 28  390.36      8   16
# 29  392.56      8   16
# 30  398.56      8   12
# 31  428.40      8   12
# 32  436.30      8   11
# 33  451.30      8   11
# 34  454.59      8   11
# 35  470.49      8   11
# 36  500.49      8   11
# 37  512.89      8    8
# 38  550.89      8    8
# 39  552.43      8    8
# 40  554.31      8    8
# 41  561.11      8    8
# 43  270.31      8    5
# 44  281.56      8    4
# 45  292.48      8    3
# 46  301.48      8    2
# 47  310.48      8    1

# %%
monthly_graph(8)

# %% [markdown]
# # September

# %%
monthly_table(9)
# Out:
#           date                                            concept  quantity  \
# 231 2022-09-28             Compra Takko 1190, Reutlingen, Tarjeta     19.97
# 232 2022-09-28  Compra Deichmann Reutlingen 1, Reutlingen, Tar...      8.99
# 233 2022-09-27  Compra Vodafone Gmbh Callya, Duesseldorf, Tarjeta     15.00
# 234 2022-09-26           Compra Rossmann 2856, Metzingen, Tarjeta      6.53
# 237 2022-09-22   Bizum A Favor De Gabriel Blanco Garcia Concepto:     45.00
# 238 2022-09-21  Compra Eb *best Of Poetry Sla, 801-413-7200, T...     25.58
# 239 2022-09-19          Compra Rewe Weber Ohg, Metzingen, Tarjeta     20.26
# 241 2022-09-16  Compra Sehne Backwaren Fil. 1, Reutlingen, Tar...      3.40
# 242 2022-09-16       Compra Amzn Mktp De*po74a5b15, 800-279-6620,     98.69
# 243 2022-09-15  Compra Sante Kg, Frankfurt, Tarjeta 5163830107...      6.00
# 244 2022-09-13  Compra Benz Wein- Und Getränk, Riederich, Tarjeta      4.49
# 245 2022-09-13    Compra Pro Op^k Augenop^k G, Metzingen, Tarjeta     24.90
# 246 2022-09-13  Compra Cineplex Deutschland G, Www.cineplex., ...     10.00
# 247 2022-09-12  Compra Sonderpreis Baumarkt, Schillingsfue, Ta...     24.83
# 248 2022-09-12       Compra Dm Drogerie Markt, Metzingen, Tarjeta     17.85
# 250 2022-09-12  Bizum A Favor De Gabriel Blanco Garcia Concept...    220.00
# 252 2022-09-08    Compra Pro Op^k Augenop^k G, Metzingen, Tarjeta      3.00
# 253 2022-09-06     Compra Habanero Restaurant, Wuerzburg, Tarjeta     14.00
# 254 2022-09-06   Compra China Restaurant Chin, Tuebingen, Tarjeta     33.00
# 256 2022-09-06  Bizum A Favor De Gabriel Blanco Garcia Concept...     50.00
# 257 2022-09-05         Compra Autohof Woernitz, Woernitz, Tarjeta     17.00
# 258 2022-09-05            Compra Db Vertrieb Gmbh, Td6xa, Tarjeta     34.05
# 259 2022-09-05  Bizum A Favor De Gabriel Blanco Garcia Concept...     12.00
# 260 2022-09-02      Compra E Center Baechner, Rothenburg, Tarjeta      1.49
#
#       saldo  month  day
# 231  140.45      9   28
# 232  160.42      9   28
# 233  169.41      9   27
# 234  184.41      9   26
# 237   96.46      9   22
# 238  141.46      9   21
# 239  167.04      9   19
# 241  182.30      9   16
# 242  185.70      9   16
# 243  284.39      9   15
# 244  290.39      9   13
# 245  294.88      9   13
# 246  319.78      9   13
# 247  329.78      9   12
# 248  354.61      9   12
# 250  172.46      9   12
# 252  282.46      9    8
# 253  285.46      9    6
# 254  299.46      9    6
# 256  132.46      9    6
# 257  182.46      9    5
# 258  199.46      9    5
# 259  233.51      9    5
# 260  245.51      9    2

# %%
monthly_graph(9)

# %% [markdown]
# # October

# %%
monthly_table(10)
# Out:
# Empty DataFrame
# Columns: [date, concept, quantity, saldo, month, day]
# Index: []

# %%
monthly_graph(10)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13328/1319284216.py in <module>
# ----> 1 monthly_graph(10)
#
# ~\AppData\Local\Temp/ipykernel_13328/3842750983.py in monthly_graph(month_number)
#       2     filter3 = expenses_by_day["month"] == month_number
#       3     data = expenses_by_day[filter3]
# ----> 4     data.plot(x="day", y="quantity", kind = "bar", title="monthly expenses")
#       5     plt.show()
#
# c:\Users\luisa\Python39\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# c:\Users\luisa\Python39\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# c:\Users\luisa\Python39\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     334         for ax in self.axes:
#     335             self._post_plot_logic_common(ax, self.data)
# --> 336             self._post_plot_logic(ax, self.data)
#     337
#     338     def _args_adjust(self):
#
# c:\Users\luisa\Python39\lib\site-packages\pandas\plotting\_matplotlib\core.py in _post_plot_logic(self, ax, data)
#    1575         name = self._get_index_name()
#    1576
# -> 1577         s_edge = self.ax_pos[0] - 0.25 + self.lim_offset
#    1578         e_edge = self.ax_pos[-1] + 0.25 + self.bar_width + self.lim_offset
#    1579
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %% [markdown]
# # November

# %%
monthly_table(11)
# Out:
# Empty DataFrame
# Columns: [date, concept, quantity, saldo, month, day]
# Index: []

# %%
monthly_graph(11)

# %% [markdown]
# # December

# %%
monthly_table(12)
# Out:
# Empty DataFrame
# Columns: [date, concept, quantity, saldo, month, day]
# Index: []

# %%
monthly_graph(12)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13328/641579901.py in <module>
# ----> 1 monthly_graph(12)
#
# ~\AppData\Local\Temp/ipykernel_13328/3842750983.py in monthly_graph(month_number)
#       2     filter3 = expenses_by_day["month"] == month_number
#       3     data = expenses_by_day[filter3]
# ----> 4     data.plot(x="day", y="quantity", kind = "bar", title="monthly expenses")
#       5     plt.show()
#
# c:\Users\luisa\Python39\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# c:\Users\luisa\Python39\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# c:\Users\luisa\Python39\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     334         for ax in self.axes:
#     335             self._post_plot_logic_common(ax, self.data)
# --> 336             self._post_plot_logic(ax, self.data)
#     337
#     338     def _args_adjust(self):
#
# c:\Users\luisa\Python39\lib\site-packages\pandas\plotting\_matplotlib\core.py in _post_plot_logic(self, ax, data)
#    1575         name = self._get_index_name()
#    1576
# -> 1577         s_edge = self.ax_pos[0] - 0.25 + self.lim_offset
#    1578         e_edge = self.ax_pos[-1] + 0.25 + self.bar_width + self.lim_offset
#    1579
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
